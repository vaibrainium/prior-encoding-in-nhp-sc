# %%
from __future__ import annotations

import argparse
import importlib.util
import logging
import sys
import time
import types
from pathlib import Path

from src.utils import pmf_utils
import pandas as pd
import matplotlib.pyplot as plt

import numpy as np
import torch

from src.ddm.ddm2 import DecisionModel, FreeParam, FixedParam

logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
logger.info(f"Using device: {device}")
# Out:
# INFO:__main__:Using device: cuda

# %%
COHERENCES     = np.array([-0.50, -0.18, -0.09, 0.0, 0.09, 0.18, 0.50]).round(2)
TRIALS_PER_COH = 150
MAX_DURATION     = 3.0
DT               = 0.001
CAF_WEIGHT       = 1
CAF_BINS         = 15
RT_VAR_WEIGHT    = 1

# %%
def plot_mean_data(data):
    fig, axes = plt.subplots(1, 3, figsize=(18, 4))

    cohs_sorted = sorted(data["signed_coherence"].unique())


    def summarize(df):
        p_upper = []
        mean_rt_upper, sem_rt_upper = [], []
        mean_rt_lower, sem_rt_lower = [], []
        for c in cohs_sorted:
            subset = df[df["signed_coherence"] == c].dropna(subset=["rt", "choice"])
            p_upper.append((subset["choice"] == 1).mean() if len(subset) > 0 else np.nan)
            upper = subset[subset["choice"] == 1]["rt"]
            lower = subset[subset["choice"] == 0]["rt"]
            mean_rt_upper.append(upper.mean() if len(upper) > 0 else np.nan)
            sem_rt_upper.append(upper.sem() if len(upper) > 0 else np.nan)
            mean_rt_lower.append(lower.mean() if len(lower) > 0 else np.nan)
            sem_rt_lower.append(lower.sem() if len(lower) > 0 else np.nan)
        return np.array(p_upper), np.array(mean_rt_upper), np.array(sem_rt_upper), np.array(mean_rt_lower), np.array(sem_rt_lower)

    p_upper, mean_rt_upper, sem_rt_upper, mean_rt_lower, sem_rt_lower = summarize(data)

    # Psychometric function
    axes[0].plot(cohs_sorted, p_upper, "o-", color="steelblue")
    axes[0].axhline(0.5, color="gray", linestyle="--", linewidth=0.8)
    axes[0].axvline(0.0, color="gray", linestyle="--", linewidth=0.8)
    axes[0].set_xlabel("Coherence")
    axes[0].set_ylabel("P(upper boundary)")
    axes[0].set_title("Psychometric Function")
    axes[0].set_ylim(0, 1)

    # Chronometric function
    mean_rt  = []
    sem_rt   = []
    for coh in cohs_sorted:
        subset = data[data["signed_coherence"] == coh].dropna()
        mean_rt.append(subset["rt"].mean())
        sem_rt.append(subset["rt"].sem())

    axes[1].errorbar(cohs_sorted, mean_rt, yerr=sem_rt, fmt="o-", color="tomato", capsize=4)
    axes[1].axvline(0.0, color="gray", linestyle="--", linewidth=0.8)
    axes[1].set_xlabel("Coherence")
    axes[1].set_ylabel("Mean RT (s)")
    axes[1].set_title("Chronometric Function")

    #
    # --- Chronometric ---

    ax2 = axes[2]
    ax2.errorbar(cohs_sorted, mean_rt_upper, yerr=sem_rt_upper, fmt="o-", color="steelblue", capsize=4, label="choice 1")
    ax2.errorbar(cohs_sorted, mean_rt_lower, yerr=sem_rt_lower, fmt="o-", color="tomato", capsize=4, label="choice 0")
    ax2.axvline(0.0, color="gray", linestyle="--", linewidth=0.8)
    ax2.set(xlabel="Coherence", ylabel="Mean RT (s)", title="Chronometric")
    ax2.legend()

    # ax2.sharey(axes[1])  # share y-axis with the middle plot|
    axes[1].sharey(ax2)  # share y-axis with the right plot

    plt.tight_layout()
    plt.show()

# for each coherence plot histogram of RTs for choice 0 and choice 1
def plot_raw_data(data):

    fig, axes = plt.subplots(len(data["signed_coherence"].unique()), 1, figsize=(8, 3 * len(data["signed_coherence"].unique())))

    for ax, coh in zip(axes, sorted(data["signed_coherence"].unique())):
        subset = data[data["signed_coherence"] == coh]
        ax.hist(subset[subset["choice"] == 0]["rt"], bins=20, alpha=0.5, label="choice 0", color="steelblue")
        ax.hist(subset[subset["choice"] == 1]["rt"], bins=20, alpha=0.5, label="choice 1", color="tomato")
        ax.set_title(f"Coherence: {coh:+.2f}")
        ax.set_xlabel("RT (s)")
        ax.set_ylabel("Count")
        ax.set_ylim(0, data["rt"].max() + 0.5)
        ax.legend()

    plt.tight_layout()
    plt.show()

# %%
fixed_params = {
    "dt": FixedParam(0.001),
    "variance": FixedParam(1.0),
}

free_params = {
    "ndt": FreeParam(0.1, 1),
    "a": FreeParam(0.8, 6.0),
    "z": FreeParam(0.1, 0.9),
    "drift_gain": FreeParam(1.0, 10.0),
    "drift_offset": FreeParam(-5.0, 5.0),
    # "variance": FreeParam(0.5, 2.0),
    "leak_rate": FreeParam(0.0, 0.3),
    "time_constant": FreeParam(-2.0, 2.0),
}

class DDMModel(DecisionModel):

    def __init__(self, fixed_params, free_params, likelihood_params=None):

        super().__init__(free_params=free_params, fixed_params=fixed_params, device=device, likelihood_params=likelihood_params)

    def _objective_function(self, values, data, stimulus, n_reps, l1_weight):
        try:
            params = self._build_params(values)
        except ValueError:
            return 1e6
        result = self._simulate_condition(stimulus, params, n_reps)
        if result is None:
            return 1e6
        return self.likelihood_calc.compute_nll(
            result["rt"], result["choice"],
            np.asarray(data["rt"]), np.asarray(data["choice"]),
            result["signed_coherence"], np.asarray(data["signed_coherence"]),
        )

ddm_model = DDMModel(
    fixed_params=fixed_params,
    free_params=free_params,
    likelihood_params={
        "caf_weight": CAF_WEIGHT,
        "caf_bins": CAF_BINS,
        "rt_var_weight": RT_VAR_WEIGHT,
    }
)
# Out:
# INFO:src.ddm.simulator:DriftDiffusionSimulator using _TorchSimulator backend on cuda
# INFO:src.ddm.ddm2:Initialized DDMModel | device=cuda

# %% [markdown]
# # Generate Data

# %%
def make_stimulus() -> np.ndarray:
    n_tp = int(MAX_DURATION / DT)
    coh  = np.repeat(COHERENCES, TRIALS_PER_COH)
    return np.tile(coh.reshape(-1, 1), (1, n_tp)).astype(np.float32)

def generate_data_simple(params: dict = None, seed: int = None):
    """Like generate_data() but uses the ddm_simple dict-based API."""
    if params is None:
        params = dict(DEFAULT_PARAMS)

    stimulus   = make_stimulus()
    sim_data = ddm_model.simulate(stimulus=stimulus, params=params, seed=seed)

    return sim_data

# %%
# calculate likelihood for original parameters (before fitting) for comparison
original_params = {
    "ndt": 0.25,
    "a": 1.0,
    "z": 0.5,
    "drift_gain": 8.0,
    "drift_offset": 0.0,
    "variance": 1.0,
    "leak_rate": 0.1,
    "time_constant": 0,#0.5,
    "dt": 0.001,

}

stimulus = make_stimulus()

data = generate_data_simple(params=original_params, seed=42)

# count number of 0, 1 and NaN in each coherence bin
summary = data.groupby("signed_coherence")["choice"].agg(
    n_trials="count",
    n_choice_0=lambda x: np.sum(x == 0),
    n_choice_1=lambda x: np.sum(x == 1),
    n_nan=lambda x: np.sum(np.isnan(x)),
).reset_index()

likelihood = ddm_model.likelihood_calc.calculate_likelihood(
    data["rt"], data["choice"],
    data["rt"], data["choice"],
    data["signed_coherence"], data["signed_coherence"],
)

print(f"Data likelihood under original parameters: {likelihood:.1f}")


print(summary)

plot_mean_data(data)
# plot_raw_data(data)
# Out:
# Data likelihood under original parameters: 0.0
#    signed_coherence  n_trials  n_choice_0  n_choice_1  n_nan
# 0             -0.50       150         148           2      0
# 1             -0.18       150         124          26      0
# 2             -0.09       150         103          47      0
# 3              0.00       150          58          92      0
# 4              0.09       150          46         104      0
# 5              0.18       150          34         116      0
# 6              0.50       150           0         150      0

# %% [markdown]
# # Recovery Trial

# %% [markdown]
# ### DDM Simple

# %%
600/7/2/2
# Out:
# 21.428571428571427

# %%
result = ddm_model.fit(
    data={"rt": data["rt"], "choice": data["choice"], "signed_coherence": data["signed_coherence"]},
    stimulus=stimulus,
    max_iterations=900,
    n_reps=15,
    l1_weight=0,
)
# Out:
# INFO:src.ddm.ddm2:Starting optimization (DDMModel)...
# WARNING:src.ddm.likelihood_calculator_working:Coherence 0.5: zero counts in observed or predicted data, skipping.
# WARNING:src.ddm.likelihood_calculator_working:Coherence 0.5: zero counts in observed or predicted data, skipping.
# WARNING:src.ddm.likelihood_calculator_working:Coherence 0.5: zero counts in observed or predicted data, skipping.
# WARNING:src.ddm.likelihood_calculator_working:Coherence 0.5: zero counts in observed or predicted data, skipping.
# WARNING:src.ddm.likelihood_calculator_working:Coherence 0.5: zero counts in observed or predicted data, skipping.
# WARNING:src.ddm.likelihood_calculator_working:Coherence 0.5: zero counts in observed or predicted data, skipping.
# WARNING:src.ddm.likelihood_calculator_working:Coherence 0.5: zero counts in observed or predicted data, skipping.
# WARNING:src.ddm.likelihood_calculator_working:Coherence 0.5: zero counts in observed or predicted data, skipping.
# WARNING:src.ddm.likelihood_calculator_working:Coherence 0.5: zero counts in observed or predicted data, skipping.
# INFO:src.ddm.ddm2:Iter   1 | NLL=296.5954 | convergence=0.0021 | ndt=0.1968  a=1.1848  z=0.3432  drift_gain=7.0953  drift_offset=0.0544  leak_rate=0.0974  time_constant=0.3516
# WARNING:src.ddm.likelihood_calculator_working:Coherence 0.5: zero counts in observed or predicted data, skipping.
# WARNING:src.ddm.likelihood_calculator_working:Coherence 0.5: zero counts in observed or predicted data, skipping.
# WARNING:src.ddm.likelihood_calculator_working:Coherence 0.5: zero counts in observed or predicted data, skipping.
# WARNING:src.ddm.likelihood_calculator_working:Coherence 0.5: zero counts in observed or predicted data, skipping.
# INFO:src.ddm.ddm2:Iter   2 | NLL=296.5954 | convergence=0.0195 | ndt=0.1968  a=1.1848  z=0.3432  drift_gain=7.0953  drift_offset=0.0544  leak_rate=0.0974  time_constant=0.3516
# WARNING:src.ddm.likelihood_calculator_working:Coherence 0.5: zero counts in observed or predicted data, skipping.
# INFO:src.ddm.ddm2:Iter   3 | NLL=296.5954 | convergence=0.0166 | ndt=0.1968  a=1.1848  z=0.3432  drift_gain=7.0953  drift_offset=0.0544  leak_rate=0.0974  time_constant=0.3516
# WARNING:src.ddm.likelihood_calculator_working:Coherence 0.5: zero counts in observed or predicted data, skipping.
# WARNING:src.ddm.likelihood_calculator_working:Coherence 0.5: zero counts in observed or predicted data, skipping.
# INFO:src.ddm.ddm2:Iter   4 | NLL=296.5954 | convergence=0.0142 | ndt=0.1968  a=1.1848  z=0.3432  drift_gain=7.0953  drift_offset=0.0544  leak_rate=0.0974  time_constant=0.3516
# WARNING:src.ddm.likelihood_calculator_working:Coherence -0.18: too few valid trials (data=150, pred=4), skipping.
# WARNING:src.ddm.likelihood_calculator_working:Coherence 0.5: zero counts in observed or predicted data, skipping.
# WARNING:src.ddm.likelihood_calculator_working:Coherence 0.5: zero counts in observed or predicted data, skipping.
# WARNING:src.ddm.likelihood_calculator_working:Coherence 0.5: zero counts in observed or predicted data, skipping.
# INFO:src.ddm.ddm2:Iter   5 | NLL=296.5954 | convergence=0.0129 | ndt=0.1968  a=1.1848  z=0.3432  drift_gain=7.0953  drift_offset=0.0544  leak_rate=0.0974  time_constant=0.3516
# WARNING:src.ddm.likelihood_calculator_working:Coherence 0.5: zero counts in observed or predicted data, skipping.
# WARNING:src.ddm.likelihood_calculator_working:Coherence 0.5: zero counts in observed or predicted data, skipping.
# INFO:src.ddm.ddm2:Iter   6 | NLL=296.5954 | convergence=0.0131 | ndt=0.1968  a=1.1848  z=0.3432  drift_gain=7.0953  drift_offset=0.0544  leak_rate=0.0974  time_constant=0.3516
# WARNING:src.ddm.likelihood_calculator_working:Coherence 0.0: too few valid trials (data=150, pred=1), skipping.
# WARNING:src.ddm.likelihood_calculator_working:Coherence 0.5: zero counts in observed or predicted data, skipping.
# INFO:src.ddm.ddm2:Iter   7 | NLL=296.5954 | convergence=0.0119 | ndt=0.1968  a=1.1848  z=0.3432  drift_gain=7.0953  drift_offset=0.0544  leak_rate=0.0974  time_constant=0.3516
# WARNING:src.ddm.likelihood_calculator_working:Coherence 0.5: zero counts in observed or predicted data, skipping.
# INFO:src.ddm.ddm2:Iter   8 | NLL=296.5954 | convergence=0.0100 | ndt=0.1968  a=1.1848  z=0.3432  drift_gain=7.0953  drift_offset=0.0544  leak_rate=0.0974  time_constant=0.3516
# WARNING:src.ddm.likelihood_calculator_working:Coherence 0.5: zero counts in observed or predicted data, skipping.
# INFO:src.ddm.ddm2:Iter   9 | NLL=280.2690 | convergence=0.0128 | ndt=0.1917  a=1.2280  z=0.4148  drift_gain=8.7671  drift_offset=-0.2293  leak_rate=0.2064  time_constant=0.3447
# WARNING:src.ddm.likelihood_calculator_working:Coherence 0.5: zero counts in observed or predicted data, skipping.
# INFO:src.ddm.ddm2:Iter  10 | NLL=280.2690 | convergence=0.0116 | ndt=0.1917  a=1.2280  z=0.4148  drift_gain=8.7671  drift_offset=-0.2293  leak_rate=0.2064  time_constant=0.3447
# INFO:src.ddm.ddm2:Iter  11 | NLL=259.7485 | convergence=0.0111 | ndt=0.2172  a=1.2669  z=0.6134  drift_gain=8.3747  drift_offset=0.3109  leak_rate=0.0357  time_constant=0.5015
# WARNING:src.ddm.likelihood_calculator_working:Coherence 0.5: zero counts in observed or predicted data, skipping.
# WARNING:src.ddm.likelihood_calculator_working:Coherence 0.5: zero counts in observed or predicted data, skipping.
# INFO:src.ddm.ddm2:Iter  12 | NLL=183.8176 | convergence=0.0133 | ndt=0.1981  a=1.2669  z=0.4578  drift_gain=8.3747  drift_offset=0.3109  leak_rate=0.2634  time_constant=0.3640
# INFO:src.ddm.ddm2:Iter  13 | NLL=176.5199 | convergence=0.0182 | ndt=0.2196  a=1.4397  z=0.4397  drift_gain=8.5680  drift_offset=0.3616  leak_rate=0.2206  time_constant=1.0367
# INFO:src.ddm.ddm2:Iter  14 | NLL=127.9329 | convergence=0.0194 | ndt=0.2048  a=1.2642  z=0.5084  drift_gain=7.4470  drift_offset=-0.1474  leak_rate=0.2359  time_constant=0.7054
# INFO:src.ddm.ddm2:Iter  15 | NLL=122.2798 | convergence=0.0177 | ndt=0.2097  a=1.3942  z=0.5030  drift_gain=8.5680  drift_offset=-0.0521  leak_rate=0.2206  time_constant=0.8695
# INFO:src.ddm.ddm2:Iter  16 | NLL=122.2798 | convergence=0.0216 | ndt=0.2097  a=1.3942  z=0.5030  drift_gain=8.5680  drift_offset=-0.0521  leak_rate=0.2206  time_constant=0.8695
# INFO:src.ddm.ddm2:Iter  17 | NLL=122.2798 | convergence=0.0221 | ndt=0.2097  a=1.3942  z=0.5030  drift_gain=8.5680  drift_offset=-0.0521  leak_rate=0.2206  time_constant=0.8695
# INFO:src.ddm.ddm2:Iter  18 | NLL=122.2798 | convergence=0.0210 | ndt=0.2097  a=1.3942  z=0.5030  drift_gain=8.5680  drift_offset=-0.0521  leak_rate=0.2206  time_constant=0.8695
# INFO:src.ddm.ddm2:Iter  19 | NLL=104.7333 | convergence=0.0272 | ndt=0.2516  a=1.0682  z=0.4536  drift_gain=8.4400  drift_offset=0.0443  leak_rate=0.2032  time_constant=0.2175
# INFO:src.ddm.ddm2:Iter  20 | NLL=104.7333 | convergence=0.0307 | ndt=0.2516  a=1.0682  z=0.4536  drift_gain=8.4400  drift_offset=0.0443  leak_rate=0.2032  time_constant=0.2175
# WARNING:src.ddm.likelihood_calculator_working:Coherence 0.0: too few valid trials (data=150, pred=3), skipping.
# INFO:src.ddm.ddm2:Iter  21 | NLL=104.7333 | convergence=0.0331 | ndt=0.2516  a=1.0682  z=0.4536  drift_gain=8.4400  drift_offset=0.0443  leak_rate=0.2032  time_constant=0.2175
# INFO:src.ddm.ddm2:Iter  22 | NLL=78.9640 | convergence=0.0293 | ndt=0.2461  a=1.0825  z=0.4872  drift_gain=8.1905  drift_offset=0.0127  leak_rate=0.1744  time_constant=0.2403
# INFO:src.ddm.ddm2:Iter  23 | NLL=78.9640 | convergence=0.0325 | ndt=0.2461  a=1.0825  z=0.4872  drift_gain=8.1905  drift_offset=0.0127  leak_rate=0.1744  time_constant=0.2403
# INFO:src.ddm.ddm2:Iter  24 | NLL=78.9640 | convergence=0.0331 | ndt=0.2461  a=1.0825  z=0.4872  drift_gain=8.1905  drift_offset=0.0127  leak_rate=0.1744  time_constant=0.2403
# INFO:src.ddm.ddm2:Iter  25 | NLL=77.7654 | convergence=0.0402 | ndt=0.2461  a=1.0505  z=0.5268  drift_gain=8.2561  drift_offset=-0.0527  leak_rate=0.1529  time_constant=0.1807
# INFO:src.ddm.ddm2:Iter  26 | NLL=77.7654 | convergence=0.0425 | ndt=0.2461  a=1.0505  z=0.5268  drift_gain=8.2561  drift_offset=-0.0527  leak_rate=0.1529  time_constant=0.1807
# INFO:src.ddm.ddm2:Iter  27 | NLL=76.1069 | convergence=0.0420 | ndt=0.2439  a=1.0318  z=0.5103  drift_gain=8.0556  drift_offset=0.0117  leak_rate=0.1440  time_constant=0.0662
# INFO:src.ddm.ddm2:Iter  28 | NLL=76.1069 | convergence=0.0406 | ndt=0.2439  a=1.0318  z=0.5103  drift_gain=8.0556  drift_offset=0.0117  leak_rate=0.1440  time_constant=0.0662
# INFO:src.ddm.ddm2:Iter  29 | NLL=76.1069 | convergence=0.0492 | ndt=0.2439  a=1.0318  z=0.5103  drift_gain=8.0556  drift_offset=0.0117  leak_rate=0.1440  time_constant=0.0662
# INFO:src.ddm.ddm2:Iter  30 | NLL=73.0724 | convergence=0.0594 | ndt=0.2461  a=1.0443  z=0.5008  drift_gain=8.2447  drift_offset=0.0175  leak_rate=0.1985  time_constant=0.1328
# INFO:src.ddm.ddm2:Iter  31 | NLL=72.1387 | convergence=0.0810 | ndt=0.2444  a=1.0421  z=0.4945  drift_gain=8.2718  drift_offset=-0.0156  leak_rate=0.1902  time_constant=0.1062
# INFO:src.ddm.ddm2:Iter  32 | NLL=70.6750 | convergence=0.0846 | ndt=0.2474  a=1.0503  z=0.5135  drift_gain=8.1762  drift_offset=-0.0588  leak_rate=0.1758  time_constant=0.1238
# INFO:src.ddm.ddm2:Iter  33 | NLL=69.9205 | convergence=0.0970 | ndt=0.2470  a=1.0675  z=0.4961  drift_gain=8.1819  drift_offset=-0.0021  leak_rate=0.1924  time_constant=0.1827
# INFO:src.ddm.ddm2:Iter  34 | NLL=67.8358 | convergence=0.1079 | ndt=0.2538  a=1.0025  z=0.5100  drift_gain=8.1481  drift_offset=-0.0397  leak_rate=0.1829  time_constant=0.0287
# INFO:src.ddm.ddm2:Iter  35 | NLL=67.1456 | convergence=0.1176 | ndt=0.2476  a=1.0003  z=0.5026  drift_gain=8.0273  drift_offset=-0.0067  leak_rate=0.1291  time_constant=0.0153
# INFO:src.ddm.ddm2:Iter  36 | NLL=67.1456 | convergence=0.1206 | ndt=0.2476  a=1.0003  z=0.5026  drift_gain=8.0273  drift_offset=-0.0067  leak_rate=0.1291  time_constant=0.0153
# INFO:src.ddm.ddm2:Iter  37 | NLL=67.1456 | convergence=0.1346 | ndt=0.2476  a=1.0003  z=0.5026  drift_gain=8.0273  drift_offset=-0.0067  leak_rate=0.1291  time_constant=0.0153
# INFO:src.ddm.ddm2:Iter  38 | NLL=67.1456 | convergence=0.1437 | ndt=0.2476  a=1.0003  z=0.5026  drift_gain=8.0273  drift_offset=-0.0067  leak_rate=0.1291  time_constant=0.0153
# INFO:src.ddm.ddm2:Iter  39 | NLL=67.1456 | convergence=0.1691 | ndt=0.2476  a=1.0003  z=0.5026  drift_gain=8.0273  drift_offset=-0.0067  leak_rate=0.1291  time_constant=0.0153
# INFO:src.ddm.ddm2:Iter  40 | NLL=66.4326 | convergence=0.1862 | ndt=0.2449  a=1.0176  z=0.5013  drift_gain=8.2222  drift_offset=-0.0351  leak_rate=0.1884  time_constant=0.0649
# INFO:src.ddm.ddm2:Iter  41 | NLL=66.4326 | convergence=0.2118 | ndt=0.2449  a=1.0176  z=0.5013  drift_gain=8.2222  drift_offset=-0.0351  leak_rate=0.1884  time_constant=0.0649
# INFO:src.ddm.ddm2:Iter  42 | NLL=66.4326 | convergence=0.2411 | ndt=0.2449  a=1.0176  z=0.5013  drift_gain=8.2222  drift_offset=-0.0351  leak_rate=0.1884  time_constant=0.0649
# INFO:src.ddm.ddm2:Iter  43 | NLL=66.4326 | convergence=0.2501 | ndt=0.2449  a=1.0176  z=0.5013  drift_gain=8.2222  drift_offset=-0.0351  leak_rate=0.1884  time_constant=0.0649
# INFO:src.ddm.ddm2:Iter  44 | NLL=66.4326 | convergence=0.2533 | ndt=0.2449  a=1.0176  z=0.5013  drift_gain=8.2222  drift_offset=-0.0351  leak_rate=0.1884  time_constant=0.0649
# INFO:src.ddm.ddm2:Iter  45 | NLL=66.4326 | convergence=0.2657 | ndt=0.2449  a=1.0176  z=0.5013  drift_gain=8.2222  drift_offset=-0.0351  leak_rate=0.1884  time_constant=0.0649
# INFO:src.ddm.ddm2:Iter  46 | NLL=66.4326 | convergence=0.2793 | ndt=0.2449  a=1.0176  z=0.5013  drift_gain=8.2222  drift_offset=-0.0351  leak_rate=0.1884  time_constant=0.0649
# INFO:src.ddm.ddm2:Iter  47 | NLL=66.4326 | convergence=0.2734 | ndt=0.2449  a=1.0176  z=0.5013  drift_gain=8.2222  drift_offset=-0.0351  leak_rate=0.1884  time_constant=0.0649
# INFO:src.ddm.ddm2:Iter  48 | NLL=66.4326 | convergence=0.2906 | ndt=0.2449  a=1.0176  z=0.5013  drift_gain=8.2222  drift_offset=-0.0351  leak_rate=0.1884  time_constant=0.0649
# INFO:src.ddm.ddm2:Iter  49 | NLL=65.8169 | convergence=0.3022 | ndt=0.2451  a=1.0271  z=0.5014  drift_gain=8.1118  drift_offset=-0.0193  leak_rate=0.1929  time_constant=0.0992
# INFO:src.ddm.ddm2:Iter  50 | NLL=65.8169 | convergence=0.3483 | ndt=0.2451  a=1.0271  z=0.5014  drift_gain=8.1118  drift_offset=-0.0193  leak_rate=0.1929  time_constant=0.0992
# INFO:src.ddm.ddm2:Iter  51 | NLL=65.4155 | convergence=0.3895 | ndt=0.2467  a=1.0298  z=0.5046  drift_gain=8.0749  drift_offset=-0.0317  leak_rate=0.0409  time_constant=0.0870
# INFO:src.ddm.ddm2:Iter  52 | NLL=65.4155 | convergence=0.4074 | ndt=0.2467  a=1.0298  z=0.5046  drift_gain=8.0749  drift_offset=-0.0317  leak_rate=0.0409  time_constant=0.0870
# INFO:src.ddm.ddm2:Iter  53 | NLL=65.4155 | convergence=0.4284 | ndt=0.2467  a=1.0298  z=0.5046  drift_gain=8.0749  drift_offset=-0.0317  leak_rate=0.0409  time_constant=0.0870
# INFO:src.ddm.ddm2:Iter  54 | NLL=65.4155 | convergence=0.4381 | ndt=0.2467  a=1.0298  z=0.5046  drift_gain=8.0749  drift_offset=-0.0317  leak_rate=0.0409  time_constant=0.0870
# INFO:src.ddm.ddm2:Iter  55 | NLL=65.4155 | convergence=0.4671 | ndt=0.2467  a=1.0298  z=0.5046  drift_gain=8.0749  drift_offset=-0.0317  leak_rate=0.0409  time_constant=0.0870
# INFO:src.ddm.ddm2:Iter  56 | NLL=65.4155 | convergence=0.5148 | ndt=0.2467  a=1.0298  z=0.5046  drift_gain=8.0749  drift_offset=-0.0317  leak_rate=0.0409  time_constant=0.0870
# INFO:src.ddm.ddm2:Iter  57 | NLL=65.4155 | convergence=0.5701 | ndt=0.2467  a=1.0298  z=0.5046  drift_gain=8.0749  drift_offset=-0.0317  leak_rate=0.0409  time_constant=0.0870
# INFO:src.ddm.ddm2:Iter  58 | NLL=65.4155 | convergence=0.6415 | ndt=0.2467  a=1.0298  z=0.5046  drift_gain=8.0749  drift_offset=-0.0317  leak_rate=0.0409  time_constant=0.0870
# INFO:src.ddm.ddm2:Iter  59 | NLL=65.4155 | convergence=0.6650 | ndt=0.2467  a=1.0298  z=0.5046  drift_gain=8.0749  drift_offset=-0.0317  leak_rate=0.0409  time_constant=0.0870
# INFO:src.ddm.ddm2:Iter  60 | NLL=64.9265 | convergence=0.6932 | ndt=0.2462  a=1.0191  z=0.5045  drift_gain=8.1234  drift_offset=-0.0266  leak_rate=0.0477  time_constant=0.0619
# INFO:src.ddm.ddm2:Iter  61 | NLL=64.8823 | convergence=0.6803 | ndt=0.2478  a=1.0100  z=0.5101  drift_gain=8.0942  drift_offset=-0.0374  leak_rate=0.0810  time_constant=0.0451
# INFO:src.ddm.ddm2:Iter  62 | NLL=64.8823 | convergence=0.7075 | ndt=0.2478  a=1.0100  z=0.5101  drift_gain=8.0942  drift_offset=-0.0374  leak_rate=0.0810  time_constant=0.0451
# INFO:src.ddm.ddm2:Iter  63 | NLL=64.8823 | convergence=0.7313 | ndt=0.2478  a=1.0100  z=0.5101  drift_gain=8.0942  drift_offset=-0.0374  leak_rate=0.0810  time_constant=0.0451
# INFO:src.ddm.ddm2:Iter  64 | NLL=64.6571 | convergence=0.7512 | ndt=0.2471  a=1.0079  z=0.5113  drift_gain=8.0719  drift_offset=-0.0415  leak_rate=0.1966  time_constant=0.0517
# INFO:src.ddm.ddm2:Iter  65 | NLL=64.6571 | convergence=0.7708 | ndt=0.2471  a=1.0079  z=0.5113  drift_gain=8.0719  drift_offset=-0.0415  leak_rate=0.1966  time_constant=0.0517
# INFO:src.ddm.ddm2:Iter  66 | NLL=64.6571 | convergence=0.7840 | ndt=0.2471  a=1.0079  z=0.5113  drift_gain=8.0719  drift_offset=-0.0415  leak_rate=0.1966  time_constant=0.0517
# INFO:src.ddm.ddm2:Iter  67 | NLL=64.6428 | convergence=0.7594 | ndt=0.2489  a=1.0038  z=0.5046  drift_gain=8.0891  drift_offset=-0.0247  leak_rate=0.2183  time_constant=0.0517
# INFO:src.ddm.ddm2:Iter  68 | NLL=64.6428 | convergence=0.7642 | ndt=0.2489  a=1.0038  z=0.5046  drift_gain=8.0891  drift_offset=-0.0247  leak_rate=0.2183  time_constant=0.0517
# INFO:src.ddm.ddm2:Iter  69 | NLL=64.6428 | convergence=0.7746 | ndt=0.2489  a=1.0038  z=0.5046  drift_gain=8.0891  drift_offset=-0.0247  leak_rate=0.2183  time_constant=0.0517
# INFO:src.ddm.ddm2:Iter  70 | NLL=64.6428 | convergence=0.7641 | ndt=0.2489  a=1.0038  z=0.5046  drift_gain=8.0891  drift_offset=-0.0247  leak_rate=0.2183  time_constant=0.0517
# INFO:src.ddm.ddm2:Iter  71 | NLL=64.6428 | convergence=0.7536 | ndt=0.2489  a=1.0038  z=0.5046  drift_gain=8.0891  drift_offset=-0.0247  leak_rate=0.2183  time_constant=0.0517
# INFO:src.ddm.ddm2:Iter  72 | NLL=64.6428 | convergence=0.7522 | ndt=0.2489  a=1.0038  z=0.5046  drift_gain=8.0891  drift_offset=-0.0247  leak_rate=0.2183  time_constant=0.0517
# INFO:src.ddm.ddm2:Iter  73 | NLL=64.6428 | convergence=0.7535 | ndt=0.2489  a=1.0038  z=0.5046  drift_gain=8.0891  drift_offset=-0.0247  leak_rate=0.2183  time_constant=0.0517
# INFO:src.ddm.ddm2:Iter  74 | NLL=64.6428 | convergence=0.7552 | ndt=0.2489  a=1.0038  z=0.5046  drift_gain=8.0891  drift_offset=-0.0247  leak_rate=0.2183  time_constant=0.0517
# INFO:src.ddm.ddm2:Iter  75 | NLL=63.4757 | convergence=0.7041 | ndt=0.2468  a=0.9986  z=0.5067  drift_gain=8.0765  drift_offset=-0.0279  leak_rate=0.2332  time_constant=0.0303
# INFO:src.ddm.ddm2:Iter  76 | NLL=63.4757 | convergence=0.6944 | ndt=0.2468  a=0.9986  z=0.5067  drift_gain=8.0765  drift_offset=-0.0279  leak_rate=0.2332  time_constant=0.0303
# INFO:src.ddm.ddm2:Iter  77 | NLL=63.4757 | convergence=0.6951 | ndt=0.2468  a=0.9986  z=0.5067  drift_gain=8.0765  drift_offset=-0.0279  leak_rate=0.2332  time_constant=0.0303
# INFO:src.ddm.ddm2:Iter  78 | NLL=63.4757 | convergence=0.7283 | ndt=0.2468  a=0.9986  z=0.5067  drift_gain=8.0765  drift_offset=-0.0279  leak_rate=0.2332  time_constant=0.0303
# INFO:src.ddm.ddm2:Iter  79 | NLL=63.4757 | convergence=0.6932 | ndt=0.2468  a=0.9986  z=0.5067  drift_gain=8.0765  drift_offset=-0.0279  leak_rate=0.2332  time_constant=0.0303
# INFO:src.ddm.ddm2:Iter  80 | NLL=63.4757 | convergence=0.7466 | ndt=0.2468  a=0.9986  z=0.5067  drift_gain=8.0765  drift_offset=-0.0279  leak_rate=0.2332  time_constant=0.0303
# INFO:src.ddm.ddm2:Iter  81 | NLL=63.4757 | convergence=0.7256 | ndt=0.2468  a=0.9986  z=0.5067  drift_gain=8.0765  drift_offset=-0.0279  leak_rate=0.2332  time_constant=0.0303
# INFO:src.ddm.ddm2:Iter  82 | NLL=63.4757 | convergence=0.7293 | ndt=0.2468  a=0.9986  z=0.5067  drift_gain=8.0765  drift_offset=-0.0279  leak_rate=0.2332  time_constant=0.0303
# INFO:src.ddm.ddm2:Iter  83 | NLL=63.4757 | convergence=0.7159 | ndt=0.2468  a=0.9986  z=0.5067  drift_gain=8.0765  drift_offset=-0.0279  leak_rate=0.2332  time_constant=0.0303
# INFO:src.ddm.ddm2:Iter  84 | NLL=63.4757 | convergence=0.6982 | ndt=0.2468  a=0.9986  z=0.5067  drift_gain=8.0765  drift_offset=-0.0279  leak_rate=0.2332  time_constant=0.0303
# INFO:src.ddm.ddm2:Iter  85 | NLL=63.4757 | convergence=0.7156 | ndt=0.2468  a=0.9986  z=0.5067  drift_gain=8.0765  drift_offset=-0.0279  leak_rate=0.2332  time_constant=0.0303
# INFO:src.ddm.ddm2:Iter  86 | NLL=63.4757 | convergence=0.7110 | ndt=0.2468  a=0.9986  z=0.5067  drift_gain=8.0765  drift_offset=-0.0279  leak_rate=0.2332  time_constant=0.0303
# INFO:src.ddm.ddm2:Iter  87 | NLL=63.4757 | convergence=0.7177 | ndt=0.2468  a=0.9986  z=0.5067  drift_gain=8.0765  drift_offset=-0.0279  leak_rate=0.2332  time_constant=0.0303
# INFO:src.ddm.ddm2:Iter  88 | NLL=63.2648 | convergence=0.7072 | ndt=0.2469  a=1.0173  z=0.5046  drift_gain=8.1755  drift_offset=-0.0334  leak_rate=0.0952  time_constant=0.0446
# INFO:src.ddm.ddm2:Iter  89 | NLL=63.2648 | convergence=0.7057 | ndt=0.2469  a=1.0173  z=0.5046  drift_gain=8.1755  drift_offset=-0.0334  leak_rate=0.0952  time_constant=0.0446
# INFO:src.ddm.ddm2:Iter  90 | NLL=63.2648 | convergence=0.7211 | ndt=0.2469  a=1.0173  z=0.5046  drift_gain=8.1755  drift_offset=-0.0334  leak_rate=0.0952  time_constant=0.0446
# INFO:src.ddm.ddm2:Iter  91 | NLL=63.2648 | convergence=0.7359 | ndt=0.2469  a=1.0173  z=0.5046  drift_gain=8.1755  drift_offset=-0.0334  leak_rate=0.0952  time_constant=0.0446
# INFO:src.ddm.ddm2:Iter  92 | NLL=63.2648 | convergence=0.7487 | ndt=0.2469  a=1.0173  z=0.5046  drift_gain=8.1755  drift_offset=-0.0334  leak_rate=0.0952  time_constant=0.0446
# INFO:src.ddm.ddm2:Iter  93 | NLL=63.2648 | convergence=0.7670 | ndt=0.2469  a=1.0173  z=0.5046  drift_gain=8.1755  drift_offset=-0.0334  leak_rate=0.0952  time_constant=0.0446
# INFO:src.ddm.ddm2:Iter  94 | NLL=63.2648 | convergence=0.7974 | ndt=0.2469  a=1.0173  z=0.5046  drift_gain=8.1755  drift_offset=-0.0334  leak_rate=0.0952  time_constant=0.0446
# INFO:src.ddm.ddm2:Iter  95 | NLL=63.2648 | convergence=0.8348 | ndt=0.2469  a=1.0173  z=0.5046  drift_gain=8.1755  drift_offset=-0.0334  leak_rate=0.0952  time_constant=0.0446
# INFO:src.ddm.ddm2:Iter  96 | NLL=63.2648 | convergence=0.8414 | ndt=0.2469  a=1.0173  z=0.5046  drift_gain=8.1755  drift_offset=-0.0334  leak_rate=0.0952  time_constant=0.0446
# INFO:src.ddm.ddm2:Iter  97 | NLL=63.2648 | convergence=0.8121 | ndt=0.2469  a=1.0173  z=0.5046  drift_gain=8.1755  drift_offset=-0.0334  leak_rate=0.0952  time_constant=0.0446
# INFO:src.ddm.ddm2:Iter  98 | NLL=63.2648 | convergence=0.8271 | ndt=0.2469  a=1.0173  z=0.5046  drift_gain=8.1755  drift_offset=-0.0334  leak_rate=0.0952  time_constant=0.0446
# INFO:src.ddm.ddm2:Iter  99 | NLL=63.2648 | convergence=0.8182 | ndt=0.2469  a=1.0173  z=0.5046  drift_gain=8.1755  drift_offset=-0.0334  leak_rate=0.0952  time_constant=0.0446
# INFO:src.ddm.ddm2:Iter 100 | NLL=63.2648 | convergence=0.8573 | ndt=0.2469  a=1.0173  z=0.5046  drift_gain=8.1755  drift_offset=-0.0334  leak_rate=0.0952  time_constant=0.0446
# INFO:src.ddm.ddm2:Iter 101 | NLL=63.2648 | convergence=0.8630 | ndt=0.2469  a=1.0173  z=0.5046  drift_gain=8.1755  drift_offset=-0.0334  leak_rate=0.0952  time_constant=0.0446
# INFO:src.ddm.ddm2:Iter 102 | NLL=63.2648 | convergence=0.8794 | ndt=0.2469  a=1.0173  z=0.5046  drift_gain=8.1755  drift_offset=-0.0334  leak_rate=0.0952  time_constant=0.0446
# INFO:src.ddm.ddm2:Iter 103 | NLL=62.9300 | convergence=0.8347 | ndt=0.2469  a=1.0255  z=0.5010  drift_gain=8.1443  drift_offset=-0.0349  leak_rate=0.1669  time_constant=0.0733
# INFO:src.ddm.ddm2:Iter 104 | NLL=62.9300 | convergence=0.8516 | ndt=0.2469  a=1.0255  z=0.5010  drift_gain=8.1443  drift_offset=-0.0349  leak_rate=0.1669  time_constant=0.0733
# INFO:src.ddm.ddm2:Iter 105 | NLL=62.9300 | convergence=0.8554 | ndt=0.2469  a=1.0255  z=0.5010  drift_gain=8.1443  drift_offset=-0.0349  leak_rate=0.1669  time_constant=0.0733
# INFO:src.ddm.ddm2:Iter 106 | NLL=62.9300 | convergence=0.8483 | ndt=0.2469  a=1.0255  z=0.5010  drift_gain=8.1443  drift_offset=-0.0349  leak_rate=0.1669  time_constant=0.0733
# INFO:src.ddm.ddm2:Iter 107 | NLL=62.9300 | convergence=0.8494 | ndt=0.2469  a=1.0255  z=0.5010  drift_gain=8.1443  drift_offset=-0.0349  leak_rate=0.1669  time_constant=0.0733
# INFO:src.ddm.ddm2:Iter 108 | NLL=62.9300 | convergence=0.8517 | ndt=0.2469  a=1.0255  z=0.5010  drift_gain=8.1443  drift_offset=-0.0349  leak_rate=0.1669  time_constant=0.0733
# INFO:src.ddm.ddm2:Iter 109 | NLL=62.9300 | convergence=0.8599 | ndt=0.2469  a=1.0255  z=0.5010  drift_gain=8.1443  drift_offset=-0.0349  leak_rate=0.1669  time_constant=0.0733
# INFO:src.ddm.ddm2:Iter 110 | NLL=62.9300 | convergence=0.8688 | ndt=0.2469  a=1.0255  z=0.5010  drift_gain=8.1443  drift_offset=-0.0349  leak_rate=0.1669  time_constant=0.0733
# INFO:src.ddm.ddm2:Iter 111 | NLL=62.9300 | convergence=0.8743 | ndt=0.2469  a=1.0255  z=0.5010  drift_gain=8.1443  drift_offset=-0.0349  leak_rate=0.1669  time_constant=0.0733
# INFO:src.ddm.ddm2:Iter 112 | NLL=62.9300 | convergence=0.8713 | ndt=0.2469  a=1.0255  z=0.5010  drift_gain=8.1443  drift_offset=-0.0349  leak_rate=0.1669  time_constant=0.0733
# INFO:src.ddm.ddm2:Iter 113 | NLL=62.9300 | convergence=0.8715 | ndt=0.2469  a=1.0255  z=0.5010  drift_gain=8.1443  drift_offset=-0.0349  leak_rate=0.1669  time_constant=0.0733
# INFO:src.ddm.ddm2:Iter 114 | NLL=62.9300 | convergence=0.8754 | ndt=0.2469  a=1.0255  z=0.5010  drift_gain=8.1443  drift_offset=-0.0349  leak_rate=0.1669  time_constant=0.0733
# INFO:src.ddm.ddm2:Iter 115 | NLL=62.9300 | convergence=0.8738 | ndt=0.2469  a=1.0255  z=0.5010  drift_gain=8.1443  drift_offset=-0.0349  leak_rate=0.1669  time_constant=0.0733
# INFO:src.ddm.ddm2:Iter 116 | NLL=62.9300 | convergence=0.9031 | ndt=0.2469  a=1.0255  z=0.5010  drift_gain=8.1443  drift_offset=-0.0349  leak_rate=0.1669  time_constant=0.0733
# INFO:src.ddm.ddm2:Iter 117 | NLL=62.9300 | convergence=0.9232 | ndt=0.2469  a=1.0255  z=0.5010  drift_gain=8.1443  drift_offset=-0.0349  leak_rate=0.1669  time_constant=0.0733
# INFO:src.ddm.ddm2:Iter 118 | NLL=62.9300 | convergence=0.9275 | ndt=0.2469  a=1.0255  z=0.5010  drift_gain=8.1443  drift_offset=-0.0349  leak_rate=0.1669  time_constant=0.0733
# INFO:src.ddm.ddm2:Iter 119 | NLL=62.9300 | convergence=0.9353 | ndt=0.2469  a=1.0255  z=0.5010  drift_gain=8.1443  drift_offset=-0.0349  leak_rate=0.1669  time_constant=0.0733
# INFO:src.ddm.ddm2:Iter 120 | NLL=62.9300 | convergence=0.9502 | ndt=0.2469  a=1.0255  z=0.5010  drift_gain=8.1443  drift_offset=-0.0349  leak_rate=0.1669  time_constant=0.0733
# INFO:src.ddm.ddm2:Iter 121 | NLL=62.9300 | convergence=0.9502 | ndt=0.2469  a=1.0255  z=0.5010  drift_gain=8.1443  drift_offset=-0.0349  leak_rate=0.1669  time_constant=0.0733
# INFO:src.ddm.ddm2:Iter 122 | NLL=62.9300 | convergence=0.9721 | ndt=0.2469  a=1.0255  z=0.5010  drift_gain=8.1443  drift_offset=-0.0349  leak_rate=0.1669  time_constant=0.0733
# INFO:src.ddm.ddm2:Iter 123 | NLL=62.9300 | convergence=0.9619 | ndt=0.2469  a=1.0255  z=0.5010  drift_gain=8.1443  drift_offset=-0.0349  leak_rate=0.1669  time_constant=0.0733
# INFO:src.ddm.ddm2:Iter 124 | NLL=62.9300 | convergence=0.9619 | ndt=0.2469  a=1.0255  z=0.5010  drift_gain=8.1443  drift_offset=-0.0349  leak_rate=0.1669  time_constant=0.0733
# INFO:src.ddm.ddm2:Iter 125 | NLL=62.9300 | convergence=0.9703 | ndt=0.2469  a=1.0255  z=0.5010  drift_gain=8.1443  drift_offset=-0.0349  leak_rate=0.1669  time_constant=0.0733
# INFO:src.ddm.ddm2:Iter 126 | NLL=62.9300 | convergence=0.9729 | ndt=0.2469  a=1.0255  z=0.5010  drift_gain=8.1443  drift_offset=-0.0349  leak_rate=0.1669  time_constant=0.0733
# INFO:src.ddm.ddm2:Iter 127 | NLL=62.9300 | convergence=0.9569 | ndt=0.2469  a=1.0255  z=0.5010  drift_gain=8.1443  drift_offset=-0.0349  leak_rate=0.1669  time_constant=0.0733
# INFO:src.ddm.ddm2:Iter 128 | NLL=62.9300 | convergence=0.9569 | ndt=0.2469  a=1.0255  z=0.5010  drift_gain=8.1443  drift_offset=-0.0349  leak_rate=0.1669  time_constant=0.0733
# INFO:src.ddm.ddm2:Iter 129 | NLL=62.9300 | convergence=0.9742 | ndt=0.2469  a=1.0255  z=0.5010  drift_gain=8.1443  drift_offset=-0.0349  leak_rate=0.1669  time_constant=0.0733
# INFO:src.ddm.ddm2:Iter 130 | NLL=62.9300 | convergence=1.0027 | ndt=0.2469  a=1.0255  z=0.5010  drift_gain=8.1443  drift_offset=-0.0349  leak_rate=0.1669  time_constant=0.0733
# INFO:src.ddm.ddm2:Optimization done. Cost: 62.9300
# INFO:src.ddm.ddm2:  dt = 0.0010
# INFO:src.ddm.ddm2:  variance = 1.0000
# INFO:src.ddm.ddm2:  ndt = 0.2469
# INFO:src.ddm.ddm2:  a = 1.0255
# INFO:src.ddm.ddm2:  z = 0.5010
# INFO:src.ddm.ddm2:  drift_gain = 8.1443
# INFO:src.ddm.ddm2:  drift_offset = -0.0349
# INFO:src.ddm.ddm2:  leak_rate = 0.1669
# INFO:src.ddm.ddm2:  time_constant = 0.0733

# %% [markdown]
# # plot model simulations

# %%
def plot_ddm_fit(data, sim, coherences=None, title="DDM Fit"):
    """
    Overlay observed data (dots) and model predictions (lines).

    data : DataFrame or dict with keys 'rt', 'choice', 'coherence'
    sim  : DataFrame or dict with keys 'rt', 'choice', 'coherence'
    """
    if not isinstance(data, pd.DataFrame):
        data = pd.DataFrame(data)
    if not isinstance(sim, pd.DataFrame):
        sim = pd.DataFrame(sim)

    cohs = sorted(coherences if coherences is not None else data["signed_coherence"].unique())

    def summarize(df):
        p_upper, mean_rt_upper, mean_rt_lower = [], [], []
        for c in cohs:
            subset = df[df["signed_coherence"] == c].dropna(subset=["rt", "choice"])
            p_upper.append((subset["choice"] == 1).mean() if len(subset) > 0 else np.nan)
            upper = subset[subset["choice"] == 1]["rt"]
            lower = subset[subset["choice"] == 0]["rt"]
            mean_rt_upper.append(upper.mean() if len(upper) > 0 else np.nan)
            mean_rt_lower.append(lower.mean() if len(lower) > 0 else np.nan)
        return np.array(p_upper), np.array(mean_rt_upper), np.array(mean_rt_lower)

    d_p, d_rt1, d_rt0 = summarize(data)
    s_p, s_rt1, s_rt0 = summarize(sim)

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))
    fig.suptitle(title)

    # --- Psychometric ---
    ax1.plot(cohs, s_p, color="steelblue", label="model")
    ax1.scatter(cohs, d_p, color="steelblue", zorder=5, label="data")
    ax1.axhline(0.5, color="gray", linestyle="--", linewidth=0.8)
    ax1.axvline(0.0, color="gray", linestyle="--", linewidth=0.8)
    ax1.set(xlabel="Coherence", ylabel="P(upper boundary)", title="Psychometric", ylim=(0, 1))
    ax1.legend()

    # --- Chronometric ---
    ax2.plot(cohs, s_rt1, color="steelblue", label="model upper")
    ax2.plot(cohs, s_rt0, color="tomato",    label="model lower")
    ax2.scatter(cohs, d_rt1, color="steelblue", zorder=5, label="data upper")
    ax2.scatter(cohs, d_rt0, color="tomato",    zorder=5, label="data lower")
    ax2.axvline(0.0, color="gray", linestyle="--", linewidth=0.8)
    ax2.set(xlabel="Coherence", ylabel="Mean RT (s)", title="Chronometric")
    ax2.legend()

    plt.tight_layout()
    return fig

# %%
# sae model results
with open("model_results_simple.pkl", "wb") as f:
    torch.save(result, f)

# %% [markdown]
# ## Likelihood Calculator

# %%
def model_comparison():
    # fitted_params = simple_model_cuda._build_params(
    #     [result["parameters"][k] for k in result["parameters"]]
    # )
    fitted_params = result["parameters"]
    sim_data = ddm_model.simulate(stimulus, params=fitted_params)
    return sim_data

# %%
with open("model_results_simple.pkl", "rb") as f:
    result = torch.load(f)

# %%
fitted_llh, origin_param_llh = [], []

sim_data_original  = ddm_model.simulate(
    stimulus, params=result["parameters"]
)

for i in range(1):
    sim_data_cuda = model_comparison()

    llh_cuda = ddm_model.likelihood_calc.calculate_likelihood(
        sim_data_cuda["rt"].values, sim_data_cuda["choice"].values,
        data["rt"].values, data["choice"].values,
        sim_data_cuda["signed_coherence"].values, data["signed_coherence"].values,
    )
    llh_original_param = ddm_model.likelihood_calc.calculate_likelihood(
        sim_data_original["rt"].values, sim_data_original["choice"].values,
        data["rt"].values, data["choice"].values,
        sim_data_original["signed_coherence"].values, data["signed_coherence"].values,
    )

    fitted_llh.append(llh_cuda)
    origin_param_llh.append(llh_original_param)

llh_data = ddm_model.likelihood_calc.calculate_likelihood(
    data["rt"].values, data["choice"].values,
    data["rt"].values, data["choice"].values,
    data["signed_coherence"].values, data["signed_coherence"].values,
)

print(f"Data vs itself:   {llh_data:.1f}  (should be 0)")
print(f"Original params:  {np.mean(origin_param_llh):.1f} ± {np.std(origin_param_llh):.1f}")
print(f"Fitted params:    {np.mean(fitted_llh):.1f} ± {np.std(fitted_llh):.1f}  (should be ≤ original)")
# Out:
# Data vs itself:   0.0  (should be 0)
# Original params:  61.7 ± 0.0
# Fitted params:    61.7 ± 0.0  (should be ≤ original)

# %%
def plot_ddm_fit(data, sim, coherences=None, title="DDM Fit"):
    """
    Overlay observed data (dots) and model predictions (lines).

    data : DataFrame or dict with keys 'rt', 'choice', 'coherence'
    sim  : DataFrame or dict with keys 'rt', 'choice', 'coherence'
    """
    if not isinstance(data, pd.DataFrame):
        data = pd.DataFrame(data)
    if not isinstance(sim, pd.DataFrame):
        sim = pd.DataFrame(sim)

    data = data.copy()
    sim  = sim.copy()
    data["signed_coherence"] = data["signed_coherence"].round(2)
    sim["signed_coherence"]  = sim["signed_coherence"].round(2)

    cohs = sorted(coherences if coherences is not None else data["signed_coherence"].unique())

    def summarize(df):
        p_upper, mean_rt_upper, mean_rt_lower = [], [], []
        for c in cohs:
            subset = df[df["signed_coherence"] == c].dropna(subset=["rt", "choice"])
            p_upper.append((subset["choice"] == 1).mean() if len(subset) > 0 else np.nan)
            upper = subset[subset["choice"] == 1]["rt"]
            lower = subset[subset["choice"] == 0]["rt"]
            mean_rt_upper.append(upper.mean() if len(upper) > 0 else np.nan)
            mean_rt_lower.append(lower.mean() if len(lower) > 0 else np.nan)
        return np.array(p_upper), np.array(mean_rt_upper), np.array(mean_rt_lower)

    d_p, d_rt1, d_rt0 = summarize(data)
    s_p, s_rt1, s_rt0 = summarize(sim)

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))
    fig.suptitle(title)

    # --- Psychometric ---
    ax1.plot(cohs, s_p, color="steelblue", label="model")
    ax1.scatter(cohs, d_p, color="steelblue", zorder=5, label="data")
    ax1.axhline(0.5, color="gray", linestyle="--", linewidth=0.8)
    ax1.axvline(0.0, color="gray", linestyle="--", linewidth=0.8)
    ax1.set(xlabel="Coherence", ylabel="P(upper boundary)", title="Psychometric", ylim=(0, 1))
    ax1.legend()

    # --- Chronometric ---
    ax2.plot(cohs, s_rt1, color="steelblue", label="model upper")
    ax2.plot(cohs, s_rt0, color="tomato",    label="model lower")
    ax2.scatter(cohs, d_rt1, color="steelblue", zorder=5, label="data upper")
    ax2.scatter(cohs, d_rt0, color="tomato",    zorder=5, label="data lower")
    ax2.axvline(0.0, color="gray", linestyle="--", linewidth=0.8)
    ax2.set(xlabel="Coherence", ylabel="Mean RT (s)", title="Chronometric")
    ax2.legend()

    plt.tight_layout()
    # return fig

# %%
plot_ddm_fit(sim_data_cuda, data, title="CUDA Fit vs Data")

# %% [markdown]
# # Trajectory Checking

# %%
# calculate likelihood for original parameters (before fitting) for comparison
original_params = {
    "ndt": 0.25,
    "a": 1.0,
    "z": 0.5,
    "drift_gain": 8.0,
    "drift_offset": 0.0,
    "variance": 1.0,
    "leak_rate": 0.1,
    "time_constant": 0,#0.5,
    "dt": 0.001,

}

stimulus = make_stimulus()
ddm_simulator = DriftDiffusionSimulator(device=device)

data = pd.DataFrame(ddm_simulator.simulate_trials(
    stimulus, params=original_params
))

# count number of 0, 1 and NaN in each coherence bin
summary = data.groupby("signed_coherence")["choice"].agg(
    n_trials="count",
    n_choice_0=lambda x: np.sum(x == 0),
    n_choice_1=lambda x: np.sum(x == 1),
    n_nan=lambda x: np.sum(np.isnan(x)),
).reset_index()


# data likelihood under original parameters
likelihood = simple_model_cuda.likelihood_calc.calculate_likelihood(
    data["rt"], data["choice"],
    data["rt"], data["choice"],
    data["signed_coherence"], data["signed_coherence"],
)

print(f"Data likelihood under original parameters: {likelihood:.1f}")


print(summary)

# plot_mean_data(data)
# plot_raw_data(data)
# Out:
# INFO:src.ddm.simulator:DriftDiffusionSimulator using _TorchSimulator backend on cuda
# Data likelihood under original parameters: 0.0
#    signed_coherence  n_trials  n_choice_0  n_choice_1  n_nan
# 0             -0.50       150         148           2      0
# 1             -0.18       150         111          39      0
# 2             -0.09       150          88          62      0
# 3              0.00       150          75          75      0
# 4              0.09       150          48         102      0
# 5              0.18       150          21         129      0
# 6              0.50       150           1         149      0

# %%
class DriftDiffusionSimulatorCUDA:
    """
    PyTorch GPU/CPU simulator.

    No-leak path: fully vectorized — cumsum builds the entire evidence
    trajectory in one shot, argmax finds the first boundary crossing.
    No Python loop over timesteps.

    Leak path: falls back to the sequential loop (leak couples timesteps,
    breaking the cumsum decomposition).
    """

    def __init__(self, device: str | None = None):
        if device == "cuda" and not torch.cuda.is_available():
            logger.warning("CUDA requested but unavailable, falling back to CPU.")
            device = "cpu"
        self.device = torch.device(
            device if device else ("cuda" if torch.cuda.is_available() else "cpu")
        )
        logger.info("Using device: %s", self.device)

    def simulate_trials(
        self, stimulus: np.ndarray | torch.Tensor, params: dict
    ) -> tuple[np.ndarray, np.ndarray]:
        dev = self.device
        if isinstance(stimulus, torch.Tensor):
            stim = stimulus.to(dev, dtype=torch.float32)
        else:
            # Cache the GPU tensor: during fitting the same numpy array is passed
            # thousands of times. Re-uploading it on every call is the main GPU
            # bottleneck. We key the cache on the array's data pointer + shape.
            ptr = stimulus.__array_interface__["data"][0]
            key = (ptr, stimulus.shape)
            if getattr(self, "_stim_cache_key", None) != key:
                self._stim_cache_key = key
                self._stim_cache     = torch.tensor(stimulus, device=dev, dtype=torch.float32)
            stim = self._stim_cache
        n_trials, n_timepoints = stim.shape
        T = n_timepoints - 1

        a             = float(params["a"])
        z             = float(params["z"])
        ndt           = float(params["ndt"])
        drift_gain    = float(params["drift_gain"])
        drift_offset  = float(params["drift_offset"])
        variance      = float(params["variance"])
        dt            = float(params["dt"])
        leak_rate     = float(params["leak_rate"])
        time_constant = float(params["time_constant"])

        sp        = z * a
        noise_std = (variance * dt) ** 0.5

        # valid[i]: step t=i+1 is live (stim not NaN)
        valid     = ~torch.isnan(stim[:, 1:])                                 # (N, T)
        drift_inc = torch.nan_to_num((drift_gain * stim[:, :-1] + drift_offset) * dt)  # (N, T)
        noise_inc = torch.randn(n_trials, T, device=dev) * noise_std          # (N, T)

        if leak_rate == 0.0:
            # ------------------------------------------------------------------
            # No-leak: evidence is a simple cumsum of increments
            # ------------------------------------------------------------------
            evidence = sp + torch.cumsum((drift_inc + noise_inc) * valid, dim=1)
        else:
            # ------------------------------------------------------------------
            # Leak: e[t] = α·e[t-1] + b[t],  α = 1 − leak·dt
            #
            # Closed-form solution via FFT convolution (no Python time loop):
            #   e[t] = αᵗ·sp  +  Σ_{j=0}^{t-1} α^{t-1-j} · b[j]
            #        = αᵗ·sp  +  (b ★ w)[t-1]   where w[k] = αᵏ
            #
            # Crossing detection uses valid mask so the decaying evidence
            # after a NaN stimulus never triggers a false crossing.
            # ------------------------------------------------------------------
            α   = 1.0 - leak_rate # * dt
            # forcing term includes the leak's pull toward sp
            # b   = (drift_inc + noise_inc + sp * leak_rate * dt) * valid       # (N, T)
            b   = (drift_inc + noise_inc + sp * leak_rate * 1) * valid       # (N, T)

            fft_n = 1 << (2 * T - 1).bit_length()   # next power-of-2 ≥ 2T-1
            k     = torch.arange(T, device=dev, dtype=torch.float32)
            w     = torch.tensor(α, device=dev, dtype=torch.float32).pow(k)   # (T,)

            particular = torch.fft.irfft(
                torch.fft.rfft(b, n=fft_n, dim=1) * torch.fft.rfft(w, n=fft_n),
                n=fft_n, dim=1,
            )[:, :T]                                                           # (N, T)

            t_exp    = torch.arange(1, T + 1, device=dev, dtype=torch.float32)
            evidence = torch.tensor(α, device=dev).pow(t_exp) * sp + particular  # (N, T)

        if time_constant != 0.0:
            t_idx        = torch.arange(1, n_timepoints, device=dev, dtype=torch.float32)
            decision_var = sp + (evidence - sp) * (1.0 + t_idx * dt * time_constant)
        else:
            decision_var = evidence

        upper   = (decision_var >= a) & valid
        lower   = (decision_var <= 0) & valid
        crossed = upper | lower

        rt     = torch.full((n_trials,), float("nan"), device=dev, dtype=torch.float32)
        choice = torch.full((n_trials,), float("nan"), device=dev, dtype=torch.float32)

        has_crossed = crossed.any(dim=1)
        if has_crossed.any():
            first_idx       = crossed[has_crossed].int().argmax(dim=1)
            rt[has_crossed] = (first_idx.float() + 1) * dt + ndt
            choice[has_crossed] = (
                upper[has_crossed]
                .gather(1, first_idx.unsqueeze(1))
                .squeeze(1)
                .float()
            )

        return rt.cpu().numpy(), choice.cpu().numpy()

# %%
def simulate_with_trajectories(params, coherences, n_per_coh=5, max_duration=MAX_DURATION, seed=0):
    """Re-run DDM simulation and return full evidence trajectories alongside rt/choice."""
    torch.manual_seed(seed)

    dt            = float(params.get("dt", DT))
    a             = float(params["a"])
    z             = float(params["z"])
    ndt           = float(params["ndt"])
    drift_gain    = float(params["drift_gain"])
    drift_offset  = float(params.get("drift_offset", 0.0))
    variance      = float(params.get("variance", 1.0))
    leak_rate     = float(params.get("leak_rate", 0.0))
    time_constant = float(params.get("time_constant", 0.0))

    n_tp     = int(max_duration / dt)
    coh_arr  = np.repeat(np.array(coherences, dtype=np.float32), n_per_coh)
    stim_t   = torch.tensor(
        np.tile(coh_arr.reshape(-1, 1), (1, n_tp)), dtype=torch.float32
    )
    N, n_timepoints = stim_t.shape
    T = n_timepoints - 1

    sp        = z * a
    noise_std = (variance * dt) ** 0.5

    valid     = ~torch.isnan(stim_t[:, 1:])
    drift_inc = torch.nan_to_num((drift_gain * stim_t[:, :-1] + drift_offset) * dt)
    noise_inc = torch.randn(N, T) * noise_std

    if leak_rate == 0.0:
        evidence = sp + torch.cumsum((drift_inc + noise_inc) * valid, dim=1)
    else:
        alpha = 1.0 - leak_rate * dt
        b     = (drift_inc + noise_inc + sp * leak_rate * dt) * valid
        fft_n = 1 << (2 * T - 1).bit_length()
        k     = torch.arange(T, dtype=torch.float32)
        w     = torch.tensor(alpha).pow(k)
        particular = torch.fft.irfft(
            torch.fft.rfft(b, n=fft_n, dim=1) * torch.fft.rfft(w, n=fft_n),
            n=fft_n, dim=1,
        )[:, :T]
        t_exp    = torch.arange(1, T + 1, dtype=torch.float32)
        evidence = torch.tensor(alpha).pow(t_exp) * sp + particular

    if time_constant != 0.0:
        t_idx        = torch.arange(1, n_timepoints, dtype=torch.float32)
        decision_var = sp + (evidence - sp) * (1.0 + t_idx * dt * time_constant)
    else:
        decision_var = evidence

    upper   = (decision_var >= a) & valid
    lower   = (decision_var <= 0) & valid
    crossed = upper | lower

    rt     = np.full(N, np.nan)
    choice = np.full(N, np.nan)
    has_crossed = crossed.any(dim=1).numpy()
    if has_crossed.any():
        first_idx = crossed[has_crossed].int().argmax(dim=1).numpy()
        rt[has_crossed]     = (first_idx + 1) * dt + ndt
        choice[has_crossed] = (
            upper[has_crossed]
            .gather(1, torch.tensor(first_idx[:, None]))
            .squeeze(1).float().numpy()
        )

    # prepend starting point so trajectories[i, 0] == sp
    trajectories = torch.cat(
        [torch.full((N, 1), sp), decision_var], dim=1
    ).numpy()

    return dict(
        trajectories=trajectories,
        coherences=coh_arr,
        rt=rt,
        choice=choice,
        t=np.arange(n_timepoints) * dt,
        a=a,
        sp=sp,
        dt=dt,
        ndt=ndt,
    )


def plot_trajectories(params, coherences=COHERENCES, n_per_coh=8, seed=42, max_t=1.5):
    res   = simulate_with_trajectories(params, coherences, n_per_coh=n_per_coh, seed=seed)
    traj  = res["trajectories"]       # (N, n_tp)
    t     = res["t"]
    cohs  = res["coherences"]
    rt    = res["rt"]
    choice = res["choice"]
    a     = res["a"]
    sp    = res["sp"]
    dt    = res["dt"]

    t_mask = t <= max_t
    t_plot = t[t_mask]

    n_cohs = len(coherences)
    ncols  = min(4, n_cohs)
    nrows  = int(np.ceil(n_cohs / ncols))
    fig, axes = plt.subplots(nrows, ncols, figsize=(3.5 * ncols, 3.5 * nrows), sharey=True)
    axes = np.array(axes).reshape(nrows, ncols)

    for idx, coh in enumerate(sorted(coherences)):
        ax   = axes[idx // ncols, idx % ncols]
        mask = np.round(cohs, 2) == round(coh, 2)

        for traj_i, rt_i, ch_i in zip(traj[mask], rt[mask], choice[mask]):
            if np.isfinite(rt_i):
                cross_step = min(int((rt_i - res["ndt"]) / dt) + 2, len(t))
                x = t[:cross_step][t[:cross_step] <= max_t]
                y = traj_i[:len(x)]
            else:
                x, y = t_plot, traj_i[t_mask]

            color = "steelblue" if ch_i == 1.0 else ("tomato" if ch_i == 0.0 else "gray")
            ax.plot(x, y, color=color, alpha=0.55, linewidth=0.9)

        ax.axhline(a,  color="k",    linestyle="--", linewidth=1.0)
        ax.axhline(0,  color="k",    linestyle="--", linewidth=1.0)
        ax.axhline(sp, color="gray", linestyle=":",  linewidth=0.8)
        ax.set_title(f"coh = {coh:+.2f}")
        ax.set_xlabel("Time (s)")
        # ax.set_xlim(0, max_t)
        ax.set_ylim(-0.15, a + 0.15)
        if idx % ncols == 0:
            ax.set_ylabel("Evidence")

    print(f"Mean RTs by coherence:")
    for coh in sorted(coherences):
        mask = np.round(cohs, 2) == round(coh, 2)
        mean_rt = np.nanmean(rt[mask])
        print(f"  coh = {coh:+.2f}: {mean_rt:.3f} s")

    # hide any unused axes
    for idx in range(n_cohs, nrows * ncols):
        axes[idx // ncols, idx % ncols].set_visible(False)

    # legend
    from matplotlib.lines import Line2D
    handles = [
        Line2D([0], [0], color="steelblue", label="upper boundary hit"),
        Line2D([0], [0], color="tomato",    label="lower boundary hit"),
        Line2D([0], [0], color="gray",      label="no decision"),
        Line2D([0], [0], color="k", linestyle="--", label="boundaries"),
        Line2D([0], [0], color="gray", linestyle=":", label="start point"),
    ]
    fig.legend(handles=handles, loc="lower center", ncol=5,
               bbox_to_anchor=(0.5, -0.02), frameon=False)
    fig.suptitle("Evidence Accumulation Trajectories", y=1.01)
    plt.tight_layout()
    plt.show()

# %%
param_1 = {
    "ndt": 0.25,
    "a": 1.0,
    "z": 0.5,
    "drift_gain": 8.0,
    "drift_offset": 0.0,
    "variance": 1.0,
    "leak_rate": 0.1,
    "time_constant": 0,#0.5,
    "dt": 0.001,
}


param_2 = {
    "ndt": 0.25,
    "a": 1.0,
    "z": 0.5,
    "drift_gain": 8.0,
    "drift_offset": 0.0,
    "variance": 1.0,
    "leak_rate": 5,
    "time_constant": 0,#0.5,
    "dt": 0.001,
}
plot_trajectories(param_1, coherences=[0.5], n_per_coh=100)
plot_trajectories(param_2, coherences=[0.5], n_per_coh=100)
# Out:
# Mean RTs by coherence:
#   coh = +0.50: 0.375 s
# Mean RTs by coherence:
#   coh = +0.50: 0.408 s
